# %%
import pandas as pd

# %%
house=pd.read_excel("E:\OnedriveSiddu\OneDrive\Documents\house.xlsx")

# %%
house
# Out:
#    S.NO       ROOM TYPE NO.OF.WINDOWS NO.OF.DOORS LIGHTS  FANS TABLES CHAIRS  \
# 0     1     LIVING ROOM         THREE         TWO   FOUR   TWO  THREE    TWO
# 1     2    DINNING HALL           TWO         ONE    TWO   ONE    ONE    SIX
# 2     3         KITCHEN           TWO         TWO    ONE   ONE    ONE   NONE
# 3     4   KID'S BEDROOM           ONE         TWO    ONE   ONE    TWO    TWO
# 4     5  MASTER BEDROOM           ONE         TWO    ONE   ONE    ONE   NONE
# 5     6     OFFICE ROOM           ONE         ONE    ONE   ONE    TWO    ONE
# 6     7         BALCONY          NONE         ONE    TWO  NONE    ONE  THREE
#
#    SOFA ELECTRONICS
# 0   ONE        FIVE
# 1  NONE         TWO
# 2  NONE         SIX
# 3  NONE        NONE
# 4  NONE         ONE
# 5  NONE         TWO
# 6  NONE        NONE

# %%
rp={"NO.OF.WINDOWS":{"ONE":1,"TWO":2,"THREE":3,"NONE":None,},
   "NO.OF.DOORS":{"ONE":1,"TWO":2},
   "LIGHTS":{"ONE":1,"TWO":2,"FOUR":4},
   "FANS":{"ONE":1,"TWO":2,"NONE":None},
   "TABLES":{"ONE":1,"TWO":2,"THREE":3}, 
   "CHAIRS":{"ONE":1,"TWO":2,"THREE":3,"SIX":6,"NONE":None},
   "SOFA":{"ONE":1,"NONE":None},
   "ELECTRONICS":{"ONE":1,"TWO":2,"FIVE":5,"SIX":6,"NONE":None}}

# %%
HOUSE=house.replace(rp)

# %%
HOUSE
# Out:
#    S.NO       ROOM TYPE  NO.OF.WINDOWS  NO.OF.DOORS  LIGHTS  FANS  TABLES  \
# 0     1     LIVING ROOM            3.0            2       4   2.0       3
# 1     2    DINNING HALL            2.0            1       2   1.0       1
# 2     3         KITCHEN            2.0            2       1   1.0       1
# 3     4   KID'S BEDROOM            1.0            2       1   1.0       2
# 4     5  MASTER BEDROOM            1.0            2       1   1.0       1
# 5     6     OFFICE ROOM            1.0            1       1   1.0       2
# 6     7         BALCONY            NaN            1       2   NaN       1
#
#    CHAIRS  SOFA  ELECTRONICS
# 0     2.0   1.0          5.0
# 1     6.0   NaN          2.0
# 2     NaN   NaN          6.0
# 3     2.0   NaN          NaN
# 4     NaN   NaN          1.0
# 5     1.0   NaN          2.0
# 6     3.0   NaN          NaN

# %%
encode={"NO.OF.WINDOWS":{"ONE":1,"TWO":2,"THREE":3,"NONE":None,},
   "NO.OF.DOORS":{"ONE":1,"TWO":2},
   "LIGHTS":{"ONE":1,"TWO":2,"FOUR":4},
   "FANS":{"ONE":1,"TWO":2,"NONE":None},
   "TABLES":{"ONE":1,"TWO":2,"THREE":3}, 
   "CHAIRS":{"ONE":1,"TWO":2,"THREE":3,"SIX":6,"NONE":None},
   "SOFA":{"ONE":1,"NONE":None},
   "ELECTRONICS":{"ONE":1,"TWO":2,"FIVE":5,"SIX":6,"NONE":None}}

# %%
encode
# Out:
# {'NO.OF.WINDOWS': {'ONE': 1, 'TWO': 2, 'THREE': 3, 'NONE': None},
#  'NO.OF.DOORS': {'ONE': 1, 'TWO': 2},
#  'LIGHTS': {'ONE': 1, 'TWO': 2, 'FOUR': 4},
#  'FANS': {'ONE': 1, 'TWO': 2, 'NONE': None},
#  'TABLES': {'ONE': 1, 'TWO': 2, 'THREE': 3},
#  'CHAIRS': {'ONE': 1, 'TWO': 2, 'THREE': 3, 'SIX': 6, 'NONE': None},
#  'SOFA': {'ONE': 1, 'NONE': None},
#  'ELECTRONICS': {'ONE': 1, 'TWO': 2, 'FIVE': 5, 'SIX': 6, 'NONE': None}}

# %%
HOUSE.info
# Out:
# <bound method DataFrame.info of    S.NO       ROOM TYPE  NO.OF.WINDOWS  NO.OF.DOORS  LIGHTS  FANS  TABLES  \
# 0     1     LIVING ROOM            3.0            2       4   2.0       3
# 1     2    DINNING HALL            2.0            1       2   1.0       1
# 2     3         KITCHEN            2.0            2       1   1.0       1
# 3     4   KID'S BEDROOM            1.0            2       1   1.0       2
# 4     5  MASTER BEDROOM            1.0            2       1   1.0       1
# 5     6     OFFICE ROOM            1.0            1       1   1.0       2
# 6     7         BALCONY            NaN            1       2   NaN       1
#
#    CHAIRS  SOFA  ELECTRONICS
# 0     2.0   1.0          5.0
# 1     6.0   NaN          2.0
# 2     NaN   NaN          6.0
# 3     2.0   NaN          NaN
# 4     NaN   NaN          1.0
# 5     1.0   NaN          2.0
# 6     3.0   NaN          NaN  >

# %%
HOUSE.shape
# Out:
# (7, 10)

# %%
HOUSE.size
# Out:
# 70

# %%
type(HOUSE)
# Out:
# pandas.core.frame.DataFrame

# %%
type(house["ROOM TYPE"])
# Out:
# pandas.core.series.Series

# %%
type(house["ELECTRONICS"])
# Out:
# pandas.core.series.Series

# %%
HOUSE.head(4)
# Out:
#    S.NO      ROOM TYPE  NO.OF.WINDOWS  NO.OF.DOORS  LIGHTS  FANS  TABLES  \
# 0     1    LIVING ROOM            3.0            2       4   2.0       3
# 1     2   DINNING HALL            2.0            1       2   1.0       1
# 2     3        KITCHEN            2.0            2       1   1.0       1
# 3     4  KID'S BEDROOM            1.0            2       1   1.0       2
#
#    CHAIRS  SOFA  ELECTRONICS
# 0     2.0   1.0          5.0
# 1     6.0   NaN          2.0
# 2     NaN   NaN          6.0
# 3     2.0   NaN          NaN

# %%
HOUSE.tail(3)
# Out:
#    S.NO       ROOM TYPE  NO.OF.WINDOWS  NO.OF.DOORS  LIGHTS  FANS  TABLES  \
# 4     5  MASTER BEDROOM            1.0            2       1   1.0       1
# 5     6     OFFICE ROOM            1.0            1       1   1.0       2
# 6     7         BALCONY            NaN            1       2   NaN       1
#
#    CHAIRS  SOFA  ELECTRONICS
# 4     NaN   NaN          1.0
# 5     1.0   NaN          2.0
# 6     3.0   NaN          NaN

# %%
HOUSE["TABLES"].value_counts()
# Out:
# 1    4
# 2    2
# 3    1
# Name: TABLES, dtype: int64

# %%
HOUSE.columns
# Out:
# Index(['S.NO', 'ROOM TYPE', 'NO.OF.WINDOWS', 'NO.OF.DOORS', 'LIGHTS', 'FANS',
#        'TABLES', 'CHAIRS', 'SOFA', 'ELECTRONICS'],
#       dtype='object')

# %%
HOUSE.isnull()
# Out:
#     S.NO  ROOM TYPE  NO.OF.WINDOWS  NO.OF.DOORS  LIGHTS   FANS  TABLES  \
# 0  False      False          False        False   False  False   False
# 1  False      False          False        False   False  False   False
# 2  False      False          False        False   False  False   False
# 3  False      False          False        False   False  False   False
# 4  False      False          False        False   False  False   False
# 5  False      False          False        False   False  False   False
# 6  False      False           True        False   False   True   False
#
#    CHAIRS   SOFA  ELECTRONICS
# 0   False  False        False
# 1   False   True        False
# 2    True   True        False
# 3   False   True         True
# 4    True   True        False
# 5   False   True        False
# 6   False   True         True

# %%
HOUSE["LIGHTS"]
# Out:
# 0    4
# 1    2
# 2    1
# 3    1
# 4    1
# 5    1
# 6    2
# Name: LIGHTS, dtype: int64

# %%
HOUSE.loc[3]
# Out:
# S.NO                         4
# ROOM TYPE        KID'S BEDROOM
# NO.OF.WINDOWS              1.0
# NO.OF.DOORS                  2
# LIGHTS                       1
# FANS                       1.0
# TABLES                       2
# CHAIRS                     2.0
# SOFA                       NaN
# ELECTRONICS                NaN
# Name: 3, dtype: object

# %%
HOUSE.iloc[6]
# Out:
# S.NO                   7
# ROOM TYPE        BALCONY
# NO.OF.WINDOWS        NaN
# NO.OF.DOORS            1
# LIGHTS                 2
# FANS                 NaN
# TABLES                 1
# CHAIRS               3.0
# SOFA                 NaN
# ELECTRONICS          NaN
# Name: 6, dtype: object

# %%
HOUSE
# Out:
#    S.NO       ROOM TYPE  NO.OF.WINDOWS  NO.OF.DOORS  LIGHTS  FANS  TABLES  \
# 0     1     LIVING ROOM            3.0            2       4   2.0       3
# 1     2    DINNING HALL            2.0            1       2   1.0       1
# 2     3         KITCHEN            2.0            2       1   1.0       1
# 3     4   KID'S BEDROOM            1.0            2       1   1.0       2
# 4     5  MASTER BEDROOM            1.0            2       1   1.0       1
# 5     6     OFFICE ROOM            1.0            1       1   1.0       2
# 6     7         BALCONY            NaN            1       2   NaN       1
#
#    CHAIRS  SOFA  ELECTRONICS
# 0     2.0   1.0          5.0
# 1     6.0   NaN          2.0
# 2     NaN   NaN          6.0
# 3     2.0   NaN          NaN
# 4     NaN   NaN          1.0
# 5     1.0   NaN          2.0
# 6     3.0   NaN          NaN

# %%
HOUSE.drop(5)
# Out:
#    S.NO       ROOM TYPE  NO.OF.WINDOWS  NO.OF.DOORS  LIGHTS  FANS  TABLES  \
# 0     1     LIVING ROOM            3.0            2       4   2.0       3
# 1     2    DINNING HALL            2.0            1       2   1.0       1
# 2     3         KITCHEN            2.0            2       1   1.0       1
# 3     4   KID'S BEDROOM            1.0            2       1   1.0       2
# 4     5  MASTER BEDROOM            1.0            2       1   1.0       1
# 6     7         BALCONY            NaN            1       2   NaN       1
#
#    CHAIRS  SOFA  ELECTRONICS
# 0     2.0   1.0          5.0
# 1     6.0   NaN          2.0
# 2     NaN   NaN          6.0
# 3     2.0   NaN          NaN
# 4     NaN   NaN          1.0
# 6     3.0   NaN          NaN

# %%
HOUSE.dropna()
# Out:
#    S.NO    ROOM TYPE  NO.OF.WINDOWS  NO.OF.DOORS  LIGHTS  FANS  TABLES  \
# 0     1  LIVING ROOM            3.0            2       4   2.0       3
#
#    CHAIRS  SOFA  ELECTRONICS
# 0     2.0   1.0          5.0

# %%
HOUSE.dropna(thresh=4)
# Out:
#    S.NO       ROOM TYPE  NO.OF.WINDOWS  NO.OF.DOORS  LIGHTS  FANS  TABLES  \
# 0     1     LIVING ROOM            3.0            2       4   2.0       3
# 1     2    DINNING HALL            2.0            1       2   1.0       1
# 2     3         KITCHEN            2.0            2       1   1.0       1
# 3     4   KID'S BEDROOM            1.0            2       1   1.0       2
# 4     5  MASTER BEDROOM            1.0            2       1   1.0       1
# 5     6     OFFICE ROOM            1.0            1       1   1.0       2
# 6     7         BALCONY            NaN            1       2   NaN       1
#
#    CHAIRS  SOFA  ELECTRONICS
# 0     2.0   1.0          5.0
# 1     6.0   NaN          2.0
# 2     NaN   NaN          6.0
# 3     2.0   NaN          NaN
# 4     NaN   NaN          1.0
# 5     1.0   NaN          2.0
# 6     3.0   NaN          NaN

# %%
x=HOUSE["LIGHTS"].mean()

# %%
x
# Out:
# 1.7142857142857142

# %%
y=HOUSE["NO.OF.DOORS"].mode()

# %%
y
# Out:
# 0    2
# Name: NO.OF.DOORS, dtype: int64

# %%
z=HOUSE["NO.OF.WINDOWS"].median()

# %%
z
# Out:
# 1.5

# %%
HOUSE.fillna(value=z)
# Out:
#    S.NO       ROOM TYPE  NO.OF.WINDOWS  NO.OF.DOORS  LIGHTS  FANS  TABLES  \
# 0     1     LIVING ROOM            3.0            2       4   2.0       3
# 1     2    DINNING HALL            2.0            1       2   1.0       1
# 2     3         KITCHEN            2.0            2       1   1.0       1
# 3     4   KID'S BEDROOM            1.0            2       1   1.0       2
# 4     5  MASTER BEDROOM            1.0            2       1   1.0       1
# 5     6     OFFICE ROOM            1.0            1       1   1.0       2
# 6     7         BALCONY            1.5            1       2   1.5       1
#
#    CHAIRS  SOFA  ELECTRONICS
# 0     2.0   1.0          5.0
# 1     6.0   1.5          2.0
# 2     1.5   1.5          6.0
# 3     2.0   1.5          1.5
# 4     1.5   1.5          1.0
# 5     1.0   1.5          2.0
# 6     3.0   1.5          1.5

# %%
HOUSE.nunique()
# Out:
# S.NO             7
# ROOM TYPE        7
# NO.OF.WINDOWS    3
# NO.OF.DOORS      2
# LIGHTS           3
# FANS             2
# TABLES           3
# CHAIRS           4
# SOFA             1
# ELECTRONICS      4
# dtype: int64

# %%
HOUSE["ROOM TYPE"]=HOUSE["ROOM TYPE"].astype("category")

# %%
HOUSE.dtypes
# Out:
# S.NO                int64
# ROOM TYPE        category
# NO.OF.WINDOWS     float64
# NO.OF.DOORS         int64
# LIGHTS              int64
# FANS              float64
# TABLES              int64
# CHAIRS            float64
# SOFA              float64
# ELECTRONICS       float64
# dtype: object

# %%
pd.get_dummies(HOUSE,columns=["NO.OF.WINDOWS"]).head()
# Out:
#    S.NO       ROOM TYPE  NO.OF.DOORS  LIGHTS  FANS  TABLES  CHAIRS  SOFA  \
# 0     1     LIVING ROOM            2       4   2.0       3     2.0   1.0
# 1     2    DINNING HALL            1       2   1.0       1     6.0   NaN
# 2     3         KITCHEN            2       1   1.0       1     NaN   NaN
# 3     4   KID'S BEDROOM            2       1   1.0       2     2.0   NaN
# 4     5  MASTER BEDROOM            2       1   1.0       1     NaN   NaN
#
#    ELECTRONICS  NO.OF.WINDOWS_1.0  NO.OF.WINDOWS_2.0  NO.OF.WINDOWS_3.0
# 0          5.0                  0                  0                  1
# 1          2.0                  0                  1                  0
# 2          6.0                  0                  1                  0
# 3          NaN                  1                  0                  0
# 4          1.0                  1                  0                  0

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
obj=OrdinalEncoder()

# %%
HOUSE["encode"]=obj.fit_transform(HOUSE[["LIGHTS"]])

# %%
HOUSE.head()
# Out:
#    S.NO       ROOM TYPE  NO.OF.WINDOWS  NO.OF.DOORS  LIGHTS  FANS  TABLES  \
# 0     1     LIVING ROOM            3.0            2       4   2.0       3
# 1     2    DINNING HALL            2.0            1       2   1.0       1
# 2     3         KITCHEN            2.0            2       1   1.0       1
# 3     4   KID'S BEDROOM            1.0            2       1   1.0       2
# 4     5  MASTER BEDROOM            1.0            2       1   1.0       1
#
#    CHAIRS  SOFA  ELECTRONICS  encode
# 0     2.0   1.0          5.0     2.0
# 1     6.0   NaN          2.0     1.0
# 2     NaN   NaN          6.0     0.0
# 3     2.0   NaN          NaN     0.0
# 4     NaN   NaN          1.0     0.0

# %%
encoded_1=HOUSE.replace(encode)

# %%
output=encoded_1.to_excel("DATA.xlsx")

# %%
pd.read_excel("DATA.xlsx")
# Out:
#    Unnamed: 0  S.NO       ROOM TYPE  NO.OF.WINDOWS  NO.OF.DOORS  LIGHTS  FANS  \
# 0           0     1     LIVING ROOM            3.0            2       4   2.0
# 1           1     2    DINNING HALL            2.0            1       2   1.0
# 2           2     3         KITCHEN            2.0            2       1   1.0
# 3           3     4   KID'S BEDROOM            1.0            2       1   1.0
# 4           4     5  MASTER BEDROOM            1.0            2       1   1.0
# 5           5     6     OFFICE ROOM            1.0            1       1   1.0
# 6           6     7         BALCONY            NaN            1       2   NaN
#
#    TABLES  CHAIRS  SOFA  ELECTRONICS  encode
# 0       3     2.0   1.0          5.0       2
# 1       1     6.0   NaN          2.0       1
# 2       1     NaN   NaN          6.0       0
# 3       2     2.0   NaN          NaN       0
# 4       1     NaN   NaN          1.0       0
# 5       2     1.0   NaN          2.0       0
# ...
